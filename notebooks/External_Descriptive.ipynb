# %% [markdown]
# # Explorative analysis of external data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import folium
from sklearn.cross_decomposition import CCA

# %%
df_geomet = pd.read_csv(os.path.abspath('../data/Processed/GeoMet.csv'), index_col=0)

print(df_geomet.shape)
df_geomet.head()
# Out:
# (331, 71)
#             City        Country        Dist_Equator Elevation Dist_to_coast  \
# 0  Baltimore(MD)  United States  4368.9466973120425       6.0             2
# 1      Melbourne      Australia   4204.749152153382      25.0             4
# 2         Niamey          Niger   1503.892924509834     209.0           781
# 3          Hanoi        Vietnam    2338.36812788643      19.0            77
# 4         Urumqi          China   4828.056360954785    2071.0          2312
#
#    wiki_link  Average high °C_Jan  Average high °C_Feb  Average high °C_Mar  \
# 0  Baltimore                  5.8                  7.6                 12.2
# 1  Melbourne                 27.0                 26.9                 24.6
# 2     Niamey                 32.5                 35.7                 39.1
# 3      Hanoi                 19.7                 20.1                 22.9
# 4     Urumqi                 -7.4                 -4.7                  2.7
#
# ...

# %% [markdown]
# ## Geographical data

# %% [markdown]
# ### Distance to equator

# %% [markdown]
# ### Distance to coast and elevation

# %%
sns.scatterplot(x = df_geomet.Elevation.values, y = df_geomet.Dist_to_coast.values)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(x = df_geomet.Elevation.values, y = df_geomet.Dist_to_coast.values)

# %%
df_geomet.Elevation.values
# Out:
# array(['6.0', '25.0', '209.0', '19.0', '2071.0', '181.0', '39.0', '44.0',
#        '219.0', '251.0', '550.0', '373.0', '89.0', '159.0', '718.0',
#        '255.0', '37.0', '-1.0', '179.0', '19.0', '11.0', '119.0', '80.0',
#        '1303.0', '8.0', '18.0', '26.0', '1571.0', '259.0', '28.0', '40.0',
#        '26.0', '226.0', '76.0', '494.0', '924.0', '21.0', '32.0', '13.0',
#        '15.0', '312.0', '78.0', '90.0', '26.0', '236.0', '90.0', '11.0',
#        '63.0', '13.0', '141.0', '138.0', '40.0', '3.0', '720.0', '509.0',
#        '14.0', '22.0', '617.0', '1578.0', '1263.0', '8.0', '83.0', '61.0',
#        '46.0', '38.0', '36.0', '219.0', '123.0', '1607.0', '0.0', '141.0',
#        '-6.0', '27.0', '1287.0', '132.0', '182.0', '19.0', '31.0', '59.0',
#        '860.0', '11.0', '156.0', '10.0', '121.0', '143.0', '103.0',
#        '1747.0', '2230.0', '30.0', '23.0', '78.0', '8.0', '137.0', '20.0',
#        '10.0', '1397.0', '12.0', '296.0', 'Birmingham,_Alabama', '15.0',
# ...

# %% [markdown]
# ## Meteorologic data

# %% [markdown]
# ## Comparison with original data
